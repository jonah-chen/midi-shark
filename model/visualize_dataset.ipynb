# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
import dotenv
from database import *
input_path = os.environ.get('pathname')
output_path = os.environ.get('dataname')
dataset = OnsetsFramesVelocity(output_path)

# %%
index = np.random.randint(0, len(dataset))
index
# Out:
# 7707

# %%
plt.figure(figsize=(20, 20))
plt.imshow(dataset[index]['real'], cmap='seismic')

plt.figure(figsize=(20, 20))
plt.imshow(dataset[index]['onsets'], cmap='gray')
plt.show()

plt.figure(figsize=(20, 20))
plt.imshow(dataset[index]['offsets'], cmap='gray')
plt.show()

plt.figure(figsize=(20, 20))
plt.imshow(dataset[index]['frames'], cmap='gray')
plt.show()

plt.figure(figsize=(20, 20))
plt.imshow(dataset[index]['velocities'], cmap='seismic')
plt.show()
